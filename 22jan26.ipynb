# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/22jan26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Financial Application for Rounding Values*
# You are developing a Financial Calculation Application for a small business that needs to handle monetary values. In financial applications, it's essential to display prices and amounts accurately, especially when dealing with user input. This application should allow users to input a float value (such as an amount of money), and then it will display the rounded-down and rounded-up values.
#
# This functionality is particularly useful in scenarios where pricing strategies might involve rounding amounts to the nearest integer for display purposes, ensuring clarity in transactions.
#
# In this scenario, the program prompts the user to input a float value representing a monetary amount. The program then calculates and displays three values:
#
# The original float value (truncated to an integer).
# The rounded-up value (using the ceil() function).
# The rounded-down value (using the floor() function).
# This output helps users see both the potential maximum and minimum rounded values associated with a given amount.

# %% [markdown]
# *Financial Application for Rounding Values*
# You are developing a Financial Calculation Application for a small business that needs to handle monetary values. In financial applications, it's essential to display prices and amounts accurately, especially when dealing with user input. This application should allow users to input a float value (such as an amount of money), and then it will display the rounded-down and rounded-up values.
#
# This functionality is particularly useful in scenarios where pricing strategies might involve rounding amounts to the nearest integer for display purposes, ensuring clarity in transactions.
#
# In this scenario, the program prompts the user to input a float value representing a monetary amount. The program then calculates and displays three values:
#
# The original float value (truncated to an integer).
# The rounded-up value (using the ceil() function).
# The rounded-down value (using the floor() function).
# This output helps users see both the potential maximum and minimum rounded values associated with a given amount.

# %% [markdown]
# *Financial Application for Rounding Values*
# You are developing a Financial Calculation Application for a small business that needs to handle monetary values. In financial applications, it's essential to display prices and amounts accurately, especially when dealing with user input. This application should allow users to input a float value (such as an amount of money), and then it will display the rounded-down and rounded-up values.
#
# This functionality is particularly useful in scenarios where pricing strategies might involve rounding amounts to the nearest integer for display purposes, ensuring clarity in transactions.
#
# In this scenario, the program prompts the user to input a float value representing a monetary amount. The program then calculates and displays three values:
#
# The original float value (truncated to an integer).
# The rounded-up value (using the ceil() function).
# The rounded-down value (using the floor() function).
# This output helps users see both the potential maximum and minimum rounded values associated with a given amount.

# %% [markdown]
# *Financial Application for Rounding Values*
# You are developing a Financial Calculation Application for a small business that needs to handle monetary values. In financial applications, it's essential to display prices and amounts accurately, especially when dealing with user input. This application should allow users to input a float value (such as an amount of money), and then it will display the rounded-down and rounded-up values.
#
# This functionality is particularly useful in scenarios where pricing strategies might involve rounding amounts to the nearest integer for display purposes, ensuring clarity in transactions.
#
# In this scenario, the program prompts the user to input a float value representing a monetary amount. The program then calculates and displays three values:
#
# The original float value (truncated to an integer).
# The rounded-up value (using the ceil() function).
# The rounded-down value (using the floor() function).
# This output helps users see both the potential maximum and minimum rounded values associated with a given amount.

# %% [markdown]
# logic is :int(amount)
# Truncates the decimal part (does not round).
# Example: int(123.75) → 123
#
# math.ceil(amount)
# Rounds up to the nearest integer.
# Example: ceil(123.75) → 124
# Useful when ensuring minimum charges.
#
# math.floor(amount)
# Rounds down to the nearest integer.
# Example: floor(123.75) → 123
# Useful for discounts or conservative pricing.

# %%
import math
n=float(input())
print(int(n))
print(math.ceil(n))
print(math.floor(n))
# Out:
# 45.78
# 45
# 46
# 45

# %% [markdown]
# *Mathematical Operations Calculator*
# You are tasked with developing a Basic Mathematical Operations Calculator for a finance application. The application allows users to perform some essential operations on two given numbers. These operations include finding the square root, power of a number, and the absolute value of a number.
#
# This type of calculator is often used in financial applications where users need to quickly compute mathematical functions like interest calculations, forecasting, or risk analysis.
#
# Write a program that takes two numbers as input from the user and performs basic mathematical operations on them, such as:
#
# Finding the square root of the first number,
# Calculating the power of the first number raised to the second number,
# Determining the absolute value of both numbers.
# The program should output the results of these mathematical functions.

# %% [markdown]
# **Logic :** math.sqrt()
# Used for calculations like volatility or risk measurements.
#
# math.pow()
# Common in compound interest and growth forecasting.
#
# abs()
# Useful for handling profits/losses without sign ambiguity.
#
# Negative check for square root
# Prevents runtime errors and ensures valid mathematical output.

# %%
import math

n1 = float(input())
n2 = float(input())

print("Square Root of first number:", math.sqrt(n1))
print("First number raised to the power of second number:", n1 ** n2)
print("Absolute value of first number:", abs(n1))
print("Absolute value of second number:", abs(n2))
# Out:
# 47.5
# 37.98
# Square Root of first number: 6.892024376045111
# First number raised to the power of second number: 4.795382936133642e+63
# Absolute value of first number: 47.5
# Absolute value of second number: 37.98

# %% [markdown]
# Student Information Management System
# You are developing a Student Information Management System for a school or university. This system allows administrators or teachers to enter and display the details of students easily. Each student has specific attributes, including their name, age, CGPA, and grade. The system will print these details in a user-friendly format when the information is entered.
#
# In this scenario, the program prompts the user to input the student's details: name (string), age (integer), CGPA (float), and grade (character). After collecting this information, the program will display the details in a structured format. The CGPA must be formatted to two decimal places to ensure readability and accuracy.
#
#
#
# Input Format
#
# The input consists of:
#
# A string representing the student's name.
#
# An integer representing the student's age.
#
# A float representing the student's CGPA.
#
# A character representing the student's grade.
#
#
#
# Output Format
#
# The program should output the student’s details in the following format:
#
# Name: [name]
#
# Age: [age]
#
# CGPA: [CGPA]
#
# Grade: [grade]
#
#
#
# Sample Input
#
# Rajeev
#
# 20
#
# 8.6467
#
# B
#
#
#
# Sample Output
#
# Name: Rajeev
#
# Age: 20
#
# CGPA: 8.64
#
# Grade: B

# %%
import math
Name=input()
Age=int(input())
CGPA=float(input())
Grade=input()
CGPA=math.floor(CGPA*100)/100

print("Name:",Name)
print("Age:",Age)
print("CGPA:",CGPA)
print("Grade:",Grade)
# Out:
# Rajeev
# 20
# 8.6467
# B
# Name: Rajeev
# Age: 20
# CGPA: 8.64
# Grade: B

# %% [markdown]
# U**ser Registration System** **
# You are developing a User Registration System for an online platform where users need to register by providing their age and name. The system needs to collect and store these details for each user to manage their profile. The age will be used to verify the eligibility of the user, while the name will be stored for identification purposes.
#
# In this scenario, the program prompts the user to input their age (as an integer) and their name (as a string). After collecting the inputs, the program prints the details in a user-friendly format. This functionality is useful for applications that require user registration, such as e-commerce platforms, social media, or any online service that needs user identification and verification.
#
#
#
# Input Format
#
# The input consists of:
#
# An integer representing the user's age.
# A string representing the user's name.
#
#
# Output Format
#
# The output should print the user's age and name in a structured format.
#
#
#
# Sample Input
#
# 25
#
# Alice
#
#
#
# Sample Output
#
# User Details:
#
# Name: Alice
#
# Age: 25

# %%
Age=input()
Name=input()

print("User Details:")
print("Name:",Name)
print("Age:",Age)
# Out:
# alice
# 25
# User Details:
# Name: 25
# Age: alice
