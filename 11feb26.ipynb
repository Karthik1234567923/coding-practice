# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/11feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Intermediate Loop Problems
# 4️⃣ Find sum of first n natural numbers

# %%
n = int(input("Enter n: "))
sum = 0

for i in range(1, n + 1):
    sum += i

print("Sum =", sum)
# Out:
# Enter n: 9
# Sum = 45
