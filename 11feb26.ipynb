# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/11feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Arithametic operaters
a=int(input())
b=int(input())
print(a+b)
print(a-b)
print(a*b)
print(a/b)


Largest among three number
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c :
    print("Largest number is ",a)
elif  b>c :
    print("Largest number is",b)
else:
    print("largest number is",c)


3. Temperature conversion
choice=int(input("Enter 1 for c to f,2 for f to c"))
if choice ==1:
    c=int(input("Enter temp in c:",c))
    f=(c*9/5)+32
    print("temp in c:",c)
elif choice==2:
    f=int(input('Enter temp in f:',f))
    c=(f-32)*5/9
    print("temp in f:",f)
else:
    print("Inlavied")

4.Type of triangle
a=int(input())
b=int(input())
c=int(input())
if a==b and b==c:
    print("Equilateral Triangle")
elif a==b or b==c or a==c:
    print("Isosclas triangle")
else:
    print("scalenes Triangle")


5. pattern printing
n = int(input())

for i in range(1, n+1):
    for j in range(i):
        print("*", end="")
    print()


   6.facorial using loop
n = int(input("Enter number: "))
fact = 1

for i in range(1, n+1):
    fact = fact * i

print("Factorial:", fact)

7. prime number :check using loops
n= int(input())

count=0
for i in range(1,n+1):
    if n% 1==0:
     count+=1
if count==2:
   print("prime number")
else:
   print("not prime number")

 8.reverse the the number
n=int(input("Enter the number"))
rev=0
while n>0 :
  digit=n%10
  rev=rev*10+digit
  n=n//10
  print("reverse a number:",rev)
