# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/20feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem: Largest Among Three Numbers
#
# Write a Python program that:
#
# Takes three numbers as input from the user
#
# Finds the largest number among them
#
# Prints the largest number

# %%
# Program to find the largest among three numbers

# Taking input from user
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
c = float(input("Enter third number: "))

# Checking the largest number
if a >= b and a >= c:
    largest = a
elif b >= a and b >= c:
    largest = b
else:
    largest = c

# Displaying the result
print("The largest number is", largest)
# Out:
# Enter first number: 45
# Enter second number: 76
# Enter third number: 73
# The largest number is 76.0
