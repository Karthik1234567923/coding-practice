# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/13feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# “Should we create modules (separate files) for this ATM project or keep it in one program?”

# %%
balance = 5000
pin = 1234

def balance_inquiry():
    print("Your balance is:", balance)

def withdraw():
    global balance
    amount = int(input("Enter withdrawal amount: "))
    if amount <= balance:
        balance -= amount
        print("Withdraw successful")
    else:
        print("Insufficient balance")

def deposit():
    global balance
    amount = int(input("Enter deposit amount: "))
    balance += amount
    print("Deposit successful")

entered_pin = int(input("Enter PIN: "))

if entered_pin == pin:

    while True:
        print("\n------ ATM MENU ------")
        print("1. Balance Inquiry")
        print("2. Cash Withdrawal")
        print("3. Cash Deposit")
        print("4. Exit")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            balance_inquiry()

        elif choice == 2:
            withdraw()

        elif choice == 3:
            deposit()

        elif choice == 4:
            print("Thank you for using ATM")
            break

        else:
            print("Invalid choice")

else:
    print("Incorrect PIN")
# Out:
# Enter PIN: 1234
#
# ------ ATM MENU ------
# 1. Balance Inquiry
# 2. Cash Withdrawal
# 3. Cash Deposit
# 4. Exit
# Enter your choice: 2
# Enter withdrawal amount: 400
# Withdraw successful
#
# ------ ATM MENU ------
# 1. Balance Inquiry
# 2. Cash Withdrawal
# 3. Cash Deposit
# 4. Exit
# Enter your choice: 3
# Enter deposit amount: 400
# Deposit successful
#
# ------ ATM MENU ------
# 1. Balance Inquiry
# 2. Cash Withdrawal
# 3. Cash Deposit
# 4. Exit
