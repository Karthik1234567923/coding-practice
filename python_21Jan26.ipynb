# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/python_21Jan26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Day 21jan 26
#arithametic operater

# %% [markdown]
# **Logic**
#
# Read two integers a and b from standard input.
#
# Perform integer division using the a//b operator and print the result.
#
# Perform float division using the a /b operator and print the result.
#
# Print each result on a new line.

# %%
a = int(input())
b = int(input())
print(a//b)
print(a/b)
# Out:
# 10
# 2
# 5
# 5.0

# %%
#Operators in Python
#1. Assignment Operators
x = 19
x += 4

print(x)
# Out:
# 23

# %%
x = 8
x -= 4

print(x)
# Out:
# 4

# %%
x =5
x *= 4

print(x)
# Out:
# 20

# %%
x = 6
x /= 4

print(x)
# Out:
# 1.5

# %% [markdown]
# **. Comparison Operators**
# Comparison operators are used to compare two values. They return either True or False depending on the condition.
#
# *Common Comparison Operators*:
# ==: Checks if two values are equal.
# !=: Checks if two values are not equal.
# >: Checks if the left operand is greater than the right operand.
# <: Checks if the left operand is less than the right operand.
# >=: Checks if the left operand is greater than or equal to the right operand.
# <=: Checks if the left operand is less than or equal to the right operand.

# %%
a = 56
b = 47
print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %% [markdown]
# 3. ***Logical Operators***
# Logical operators are used to combine conditional statements. They evaluate expressions and return either True or False.
#
# Common Logical Operators *:
# 1. and: Returns True if both conditions are true.
# 2. or: Returns True if at least one condition is true.
# 3. not: Reverses the logical state of its operand (True becomes False, and vice versa)

# %%
y = 45
x =78
print(x < 50 and y >40)
print(x > 45 or y  >10)
print(not(x < 50 and y >40))
# Out:
# False
# True
# True

# %% [markdown]
# 4. Membership Operators

# %%
my_list = [ 1,5,6,7,]
my_string = "karthik"

print(6 in my_list)
print("k" in my_string)
print(9 not in my_list)
print(6 not in my_list)
# Out:
# True
# True
# True
# False

# %%
#bitwise operaters
a = 5
b = 3
print(a & b)
print(a | b)
print(a ^ b)
print(~a)
print(a << b)
print(a >> b )
# Out:
# 1
# 7
# 6
# -6
# 40
# 0
