# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/12feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= int(input('enter the number'))
b= int(input())
c= int(input())
if a>b and a>c:
    print("largest number is:",a)
elif b>c:
   print("largest number is:",b)
else :
   print("largest number is:",c)
# Out:
# enter the number34
# 77
# 88
# largest number is: 88
