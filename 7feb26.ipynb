# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/7feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Arithemetic operateres

# %%
a=int(input())
b=int(input())
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 8
# 9
# 17
# -1
# 72
# 0.8888888888888888

# %% [markdown]
# 2. Largest among three number

# %%
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c :
   print("a is greatest number")
elif b>a :
  print("b is greatest number")
else :
  print("c is greatest number")
# Out:
# 5
# 9
# 7
# b is greatest number
