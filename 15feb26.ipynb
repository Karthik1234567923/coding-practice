# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/15feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 3: Reverse Star Pattern
# Output
# * * * *
# * * *
# * *
# *

# %%
rows = 4

for i in range(rows, 0, -1):
    for j in range(i):
        print("*", end=" ")
    print()
# Out:
# * * * *
# * * *
# * *
# *
