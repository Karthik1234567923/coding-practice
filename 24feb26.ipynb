# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/24feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Function to Check Even or Odd

# %%
def check_even_odd(n):
    if n % 2 == 0:
        print("Even")
    else:
        print("Odd")

num = int(input("Enter number: "))
check_even_odd(num)
# Out:
# Enter number: 34
# Even
