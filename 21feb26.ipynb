# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik1234567923/coding-practice/blob/coding---practice/21feb26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Handle Invalid Input
# Question
#
# Handle error when user enters string instead of number.

# %%
try:
    num = int(input("Enter number: "))
    print("You entered:", num)

except ValueError:
    print("Invalid input! Enter only integer.")
# Out:
# Enter number: 12
# You entered: 12
